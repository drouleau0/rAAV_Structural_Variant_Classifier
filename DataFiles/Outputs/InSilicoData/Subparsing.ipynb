# %%
# %%bash
# export PATH=/opt/oxb/ngs/binaries/python-3.10.12/bin:$PATH
#
# payload_size=2865
#
# input_file_directory=../../Inputs/InSilicoData/tiling/
#
# # Find all files with the specified extension in the directory and store in an array
# input_files=($(find "$input_file_directory" -type f -name *.tile.zmw.counts))
#
# # Check if any files were found
# if [[ ${#input_files[@]} -eq 0 ]]; then
#   echo "No files with extension *.tile.zmw.counts found in '$directory'."
#   exit 1
# fi
#
# # Put the desired output directory into this variable
# # IMPORTANT NOTE: make sure the path ends with a "/" or the output file organization will not be correct
# output_directory="subparsing/"
#
#
# # Do Not Modify anything below here unless you want to add optional arguments
# vector_subparser="../../../CodeFiles/parse_file.py"
# for i in ${!input_files[@]}; do
#     printf "running ${input_files[$i]} with payload size ${payload_size}\n"
#     if python3 $vector_subparser -i ${input_files[$i]} -o $output_directory -p ${payload_size} -s -u; then # add optional arguments on this line before the semicolon
#         printf "succesfully run ${input_files[$i]} with payload size ${payload_size}\n"
#     else
#         printf 'failure in vector subparsing\n'
#     fi
# done
# printf 'done all'
# Out:
# running ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_001.fasta.tile.zmw.counts with payload size 2865
# succesfully run ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_001.fasta.tile.zmw.counts with payload size 2865
# running ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_01.fasta.tile.zmw.counts with payload size 2865
# succesfully run ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_01.fasta.tile.zmw.counts with payload size 2865
# running ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_05.fasta.tile.zmw.counts with payload size 2865
# succesfully run ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_05.fasta.tile.zmw.counts with payload size 2865
# running ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_0.fasta.tile.zmw.counts with payload size 2865
# succesfully run ../../Inputs/InSilicoData/tiling/extended_species_endITR_m_0.fasta.tile.zmw.counts with payload size 2865
# ...

# %% [markdown]
# ## Unit Testing: Run only if making modifications

# %%
# %%bash
#
# test_code="../../../CodeFiles/test_vector_subparser.py"
#
# export PATH=/opt/oxb/ngs/binaries/python-3.10.12/bin:$PATH
#
# python3 $test_code -v
# Out:
# test_FileParser_constructor (__main__.TestFileParser) ... ok
# test_bin_tilelines (__main__.TestFileParser) ... ok
# test_calculate_bin_proportions (__main__.TestFileParser) ... ok
# test_extended_payload_name (__main__.TestFileParser) ... ok
# test_group_categories (__main__.TestFileParser) ... ok
# test_process_U_line (__main__.TestFileParser) ... ok
# test_process_line (__main__.TestFileParser) ... ok
# test_process_x_2_line (__main__.TestFileParser) ... ok
# test_Tile_constructor (__main__.TestTile) ... ok
# test_Tile_payload_sizing (__main__.TestTile) ... ok
# test_compare_tiles (__main__.TestTile) ... ok
# test_coordinates_are_equal (__main__.TestTile) ... ok
# test_equality (__main__.TestTile) ... ok
# test_set_is_full (__main__.TestTile) ... ok
# test_TileLineBin_constructor (__main__.TestTileBin) ... ok
# test_calculate_full_proportions (__main__.TestTileBin) ... ok
# test_Tileline_constructor (__main__.TestTileLine) ... ok
# ...
